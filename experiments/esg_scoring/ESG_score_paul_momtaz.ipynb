# %% [markdown]
# This notebook presents a bot to calculate ESG Scoref from a list of companies divided in
#
# - The data collection
# - ESG calculation using the calculation of the ESG score based on the method introduced in the paper Sustainable Entrepreneurship: Identification of Startups' ESG Properties from Text Data with Machine Learning

# %% [markdown]
# Python code for the calculation of the ESG score based on available code at sustainableentrepreneurship.org
# - https://github.com/sasi2400/sustainableentrepreneurship.org/blob/main/Notebooks/ESG%20score%20calculation.ipynb

# %% [markdown]
# # 1 - Imports and methods

# %%
# import required packages
import pandas as pd
import numpy as np
import re
from cleantext import clean # install via: pip install clean-text

#import the word-lists
ESGwordlist= pd.read_csv('https://www.dropbox.com/s/e28dihonntg8o82/expanded_dict.csv?dl=1')
e = [x.replace('_',' ') for x in list(ESGwordlist['E'].dropna())]
s = [x.replace('_',' ') for x in list(ESGwordlist['S'].dropna())]
g = [x.replace('_',' ') for x in list(ESGwordlist['G'].dropna())]

# %%
# packages required for scraping
import requests
import re
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup

from urllib.request import urlopen

# %%
# required methods
def get_ngrams(s, n):
    '''
    tokenize an input text 
    source: https://albertauyeung.github.io/2018/06/03/generating-ngrams.html
    '''
    # Convert to lowercases
    s = s.lower()
    
    # Replace all none alphanumeric characters with spaces
    s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
    
    # Break sentence in the token, remove empty tokens
    tokens = [token for token in s.split(" ") if token != ""]
    
    # Use the zip function to help us generate n-grams
    # Concatentate the tokens into ngrams and return
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

def cleaner(txt):    
    '''
    Clean the input text
    '''
    return clean(
        txt,
        fix_unicode=True,               # fix various unicode errors
        to_ascii=True,                  # transliterate to closest ASCII representation
        lower=True,                     # lowercase text
        no_line_breaks=True,           # fully strip line breaks as opposed to only normalizing them
        no_urls=True,                  # replace all URLs with a special token
        no_emails=True,                # replace all email addresses with a special token
        no_phone_numbers=True,         # replace all phone numbers with a special token
        no_numbers=True,                # replace all numbers with a special token
        no_digits=True,                 # replace all digits with a special token
        no_currency_symbols=True,      # replace all currency symbols with a special token
        no_punct=True,                 # remove punctuations
        replace_with_punct="",          # instead of removing punctuations you may replace them
        replace_with_url="",
        replace_with_email="",
        replace_with_phone_number="",
        replace_with_number="",
        replace_with_digit="",
        replace_with_currency_symbol="",
        lang="en"                       # set to 'de' for German special handling
        )

# %% [markdown]
# # 2 - ESG Calculator

# %%
def ESG_Calculator(text):
    '''
    return the ESG scores for an input text
    '''
    try:      
        text=re.sub('[\\n]','',text)
        text=get_ngrams(text,1)+get_ngrams(text,2)+get_ngrams(text,3)+get_ngrams(text,4)
        counts=[]
        counts= [text.count(x) for x in e]
        e_Freq=sum(counts) 
        e_Diversity = len([x for x in counts if x!=0])    
        counts= [text.count(x) for x in s]
        s_Freq=sum(counts) 
        s_Diversity = len([x for x in counts if x!=0])            
        counts= [text.count(x) for x in g]
        g_Freq=sum(counts) 
        g_Diversity = len([x for x in counts if x!=0])    
        esg_Diversity= e_Diversity/len(e) +s_Diversity/len(s) +g_Diversity/len(g)
        return (esg_Diversity,(e_Diversity/len(e)),(s_Diversity/len(s)),(g_Diversity/len(g)))
    except Exception as ex:
        print(ex)
        return (0,0,0,0)

# %%
def mostreESG(ESG):
    print('''
            ESG Score: {0}  \n
            Environmental Score: {1}  \n
            Social Score: {2} \n
            Governance Score {3} 
            '''.format(np.round(ESG[0], 3),np.round(ESG[1], 3),np.round(ESG[2], 3),np.round(ESG[3], 3)))

# %%
import csv

AllData = []
count=0
with open('../../data/icobase/TOTAL_ICOMARKS.csv') as argsFile:
	spamreader = csv.reader(argsFile, delimiter=',')
	for row in spamreader:
		if row[2].find(".html") == -1:
			row[2] = row[2] + ".html"
			count=count+1
		AllData.append(row)
header = AllData.pop(0)

# %%
import csv

path = '../../data/'
AllData = []
count=0
with open(path+'icobase/TOTAL_ICOMARKS.csv') as argsFile:
	spamreader = csv.reader(argsFile, delimiter=',')
	for row in spamreader:
		AllData.append(row)
header = AllData.pop(0)

# %% [markdown]
# ## WebScout ESG
#   - Designed to automate the process of gathering and analyzing data from a list of web addresses.
#   - It systematically visits each provided URL, extracts relevant textual content—most likely company
#     descriptions—and or whitepapers
# - Use the function *ESG_Calculator*, to compute Environmental, Social, and Governance (ESG) scores
#    based on the extracted text of each company, and integrated the ESG scores back into the original
#    data structure (`AllData`).
# - **Note:** the script incorporates robust error handling mechanisms to manage potential issues
#   during network requests and maintains a record of any URLs that could not be successfully processed,
#   allowing for subsequent review or re-attempt.

# %%
ammntICOs = len(AllData)
failed_urls = []
for i in range(ammntICOs-1):
    url = AllData[i][2]
    #response = None
    try:
        response = requests.get(url) #, timeout=3)
        response.raise_for_status()
    except requests.exceptions.RequestException as err:
        print ("OOps: Something Else",err)
    except requests.exceptions.HTTPError as errh:
        print ("Http Error:",errh)
    except requests.exceptions.ConnectionError as errc:
        print ("Error Connecting:",errc)
    except requests.exceptions.Timeout as errt:
        print ("Timeout Error:",errt)  
    if response:
        # parse the HTML content of the page
        soup = BeautifulSoup(response.content, "html.parser")
        product_search_element = soup.find(id="company-description")
        list_item = soup.find('div', attrs={'class': 'company-description'})
        text = list_item.text.strip()
        ESG = ESG_Calculator(text)
        AllData[i][3] = np.round(ESG[0], 3)
        AllData[i][4] = np.round(ESG[1], 3)
        AllData[i][5] = np.round(ESG[2], 3)
        AllData[i][6] = np.round(ESG[3], 3)
        #mostreESG(ESG)
    else:
        failed_urls.append(url)
# Out:
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Flash
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/black-wave
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/livetree
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Digipay-Network
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Azuma-Games
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/blockchain/the-ux
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/TAGZ
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/EasyDex
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/CRYPTO-TRON-EXCHANGE-AND-SHOP
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/CareerXon
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Larecoin-(LARE)
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Notarchain.es
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Nuvus.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/opakeco
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Qilin.Market
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/SocialMedia.Market
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Hedge.pro
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Incremint.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/MASS.cloud
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Nami.Trade
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/SmartGenie.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/thx!-(IEO-at-Liquid-by-Quoine)
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Bankcoin-(BCASH)-Platform
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/dock.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Electrify.Asia
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Nexinter-(IEO)
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/YuTu.Coin
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/KAASY.AI
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/McFly.aero
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Rialto.AI
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/traceto.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/IBFS.world
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/algo.land
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/cannabisfarm.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/dueltoken.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Ethereum.link
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Lendium.tech
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/bmy.guide
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/DOX.NETWORK
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/EtherJack.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Pontem-Inc.
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/sexService.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Stocks.Bet
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/folio.ninja
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/U.CASH
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/LOLTOKEN-BY-EIU.AC
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Geco.one
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/idap.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Carbon-Offset-Initiative
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/K.im
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Airsave-Travel
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Flyp.me
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Krypti.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Xtake.cash
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Jinbi-Token
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/WaykiChain-(WGRT/WUSD)
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Jun-&#034;M&%23034;-Coin
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/eden.best
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/AI-PowerBrain.Shop
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/MediaRich.io
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/MyBtcfX-(4xBIT)
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Atlantis-Blue
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/SmartContainers
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Biwo-Exchange
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Insolar
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/YearnClassic.Finance
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/BR11-Token
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Scopuly-SKY
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Mama-Mutua
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Bolton-Coin
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Sonata.ai
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/BRAVO-Pay
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/EatMeCoin
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/Eqwity-Studio
# OOps: Something Else 404 Client Error: Not Found for url: https://icomarks.com/ico/MiL.K

# %% [markdown]
# - ico_notfound is alist of URLs that could not be successfully processed

# %%
import csv 

ammnt_failed = len(failed_urls)
tam = len(AllData)

copy = failed_urls
    
ico_notfound = []
ico_notfound.append(['id', 'name', 'url', 'ESG', 'E', 'S', 'G'])

for i in range(ammnt_failed):  
    notfound = True 
    j = 0
    while notfound and j < tam:
        if failed_urls[i] == AllData[j][2]:
            ico_notfound.append([AllData[j][0],AllData[j][1],copy[i],AllData[j][3],AllData[j][4],AllData[j][5],AllData[j][6]])
            notfound = False
        else:
            j= j + 1
len(ico_notfound)
# Out:
# 76

# %%
# FALHAS_ICOMARKS.csv has all companies url that failed to load 
import csv 
path = '../../data/'
filename = path+'icobase/FALHAS_ICOMARKS.csv'
with open(filename, 'w', newline="") as newfile:
	csvwriter = csv.writer(newfile)
#	csvwriter.writerow(header[0])
	csvwriter.writerows(ico_notfound)
newfile.close()

# %%
DataFoundico = []

with open(path+'icobase/TOTAL_FOUNDICO.csv') as argsFile:
	spamreader = csv.reader(argsFile, delimiter=',')
	for row in spamreader:
		DataFoundico.append(row)
headerOf = DataFoundico.pop(0)
ammntFoundico = len(DataFoundico)

# %%
failed_foundico_urls = []
ammntFoundico = len(DataFoundico)
for i in range(ammntFoundico-1):
    url = DataFoundico[i][2]
#    response = requests.get(url)   
    try:
        response = requests.get(url) #, timeout=3)
        response.raise_for_status()
    except requests.exceptions.RequestException as err:
        print ("OOps: Something Else",err)
    except requests.exceptions.HTTPError as errh:
        print ("Http Error:",errh)
    except requests.exceptions.ConnectionError as errc:
        print ("Error Connecting:",errc)
    except requests.exceptions.Timeout as errt:
        print ("Timeout Error:",errt)  
    if response:
        # parse the HTML content of the page
        print(url)
        soup = BeautifulSoup(response.content, "html.parser")
        lista = soup.find_all('p')
        text = soup.find_all('p')[1].get_text()
        #text = list_item.text.strip()
        ESG = ESG_Calculator(text)
        DataFoundico[i][3] = np.round(ESG[0], 3)
        DataFoundico[i][4] = np.round(ESG[1], 3)
        DataFoundico[i][5] = np.round(ESG[2], 3)
        DataFoundico[i][6] = np.round(ESG[3], 3)
        #mostreESG(ESG)
    else:
        failed_foundico_urls.append(url)
# Out:
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/greenenergy.html
# https://foundico.com/ico/PowerCorp.HTML
# https://foundico.com/ico/HERO-Token.HTML
# https://foundico.com/ico/PowerLoan.HTML
# https://foundico.com/ico/Gene-Blockchain-Token.HTML
# https://foundico.com/ico/Vinnd.HTML
# https://foundico.com/ico/SmartHealthcareToday.HTML
# https://foundico.com/ico/NWP-solution.HTML
# https://foundico.com/ico/THEBIKECOIN.HTML
# https://foundico.com/ico/HUSSY.HTML
# https://foundico.com/ico/Wind-Energy-Mining.HTML
# https://foundico.com/ico/GMP-Project.HTML
# https://foundico.com/ico/Industria.HTML
# https://foundico.com/ico/Seratio-Platform.HTML
# https://foundico.com/ico/TuteCoin.HTML
# https://foundico.com/ico/Clear-Shop-Vision-ORC.HTML
# https://foundico.com/ico/TrustedCars-Flex.HTML
# https://foundico.com/ico/LEONARDO.HTML
# https://foundico.com/ico/Cher-Ecocity.HTML
# https://foundico.com/ico/flat-earth-coin-.html
# https://foundico.com/ico/CryptoHunters.HTML
# https://foundico.com/ico/Izzy-Care.HTML
# https://foundico.com/ico/CustomCoin-Platform.HTML
# https://foundico.com/ico/tradeio.html
# https://foundico.com/ico/Robot-Vera.HTML
# https://foundico.com/ico/esportscom.html
# https://foundico.com/ico/Leap-With-Alice.HTML
# https://foundico.com/ico/Miniera.HTML
# https://foundico.com/ico/Smart-City-Coin-Test-Net.HTML
# https://foundico.com/ico/Monarchy-investment.HTML
# https://foundico.com/ico/TurkeyEnergyToken.HTML
# https://foundico.com/ico/Uulula.HTML
# https://foundico.com/ico/BEAT.HTML
# https://foundico.com/ico/LusoCoin.HTML
# https://foundico.com/ico/Delivery-Power-Token.HTML
# https://foundico.com/ico/The-Imigize-Service-Blockchain.HTML
# https://foundico.com/ico/FRELDO.HTML
# https://foundico.com/ico/REcoin.HTML
# https://foundico.com/ico/Tangle-Coins.HTML
# https://foundico.com/ico/Adosia.HTML
# https://foundico.com/ico/Leverage-Platform.HTML
# https://foundico.com/ico/HiP.HTML
# https://foundico.com/ico/payperEx.HTML
# https://foundico.com/ico/TEMBOCOIN.HTML
# https://foundico.com/ico/max-crowdfund.html
# https://foundico.com/ico/FOODCOIN-ECOSYSTEM.HTML
# https://foundico.com/ico/Demeter.HTML
# https://foundico.com/ico/new-waste-treatment-system-.html
# https://foundico.com/ico/sprinto.HTML
# https://foundico.com/ico/SmartAgro.HTML
# https://foundico.com/ico/injii-Access-Coin.HTML
# https://foundico.com/ico/Vaynix.HTML
# https://foundico.com/ico/I-am-by-Infobeing.HTML
# https://foundico.com/ico/BOCCio.HTML
# https://foundico.com/ico/Potion-Owl.HTML
# https://foundico.com/ico/Secure-Crypto-Payments.HTML
# https://foundico.com/ico/Karatcoin.HTML
# https://foundico.com/ico/findexchange.html
# https://foundico.com/ico/Auctus-Project.HTML
# https://foundico.com/ico/Creditcoin-on-FLATLAY.HTML
# https://foundico.com/ico/Signals-Network.HTML
# https://foundico.com/ico/Rhizome-Network-Protocol.HTML
# OOps: Something Else Invalid URL 'foundico.com/ico/fetch-ai.html': No scheme supplied. Perhaps you meant http://foundico.com/ico/fetch-ai.html?
# foundico.com/ico/fetch-ai.html
# https://foundico.com/ico/RGB-market.HTML
# https://foundico.com/ico/Cryptonetix.HTML
# https://foundico.com/ico/bitcoinhomework-extracredit.html
# https://foundico.com/ico/QUASAR-COIN.HTML
# https://foundico.com/ico/Fleetcoin.HTML
# https://foundico.com/ico/FACHAIN.HTML
# https://foundico.com/ico/BTRIC.HTML
# https://foundico.com/ico/Larecoin.HTML
# https://foundico.com/ico/Educhambers.HTML
# https://foundico.com/ico/MBYZ.HTML
# https://foundico.com/ico/Pablo-Plus.HTML
# https://foundico.com/ico/Catholic-coin.HTML
# https://foundico.com/ico/MinerOne.HTML
# https://foundico.com/ico/ETM-COIN.HTML
# https://foundico.com/ico/Restart-Energy-Democracy.HTML
# https://foundico.com/ico/Torus.HTML
# https://foundico.com/ico/Gmine.HTML
# https://foundico.com/ico/GRYisPower.HTML
# https://foundico.com/ico/CyberTechNET.HTML
# https://foundico.com/ico/JTK-Ultrade-Group.HTML
# https://foundico.com/ico/XCENT.HTML
# https://foundico.com/ico/GoMineWorld.HTML
# https://foundico.com/ico/Florio.HTML
# https://foundico.com/ico/SHIVOM.HTML
# https://foundico.com/ico/Health-FX.HTML
# https://foundico.com/ico/TheChampcoin-Gold.HTML
# https://foundico.com/ico/EyeGlob.HTML
# https://foundico.com/ico/SilentNotary.HTML
# https://foundico.com/ico/CZERO-MOBILITY.HTML
# https://foundico.com/ico/DriveDeal.HTML
# https://foundico.com/ico/genevi-ve-vc.html
# https://foundico.com/ico/makersmarks-decentralized-product-identification.html
# https://foundico.com/ico/Oxycoin.HTML
# https://foundico.com/ico/Starbase-Co.HTML
# https://foundico.com/ico/des--antiscam.html
# https://foundico.com/ico/NaPoleonX.HTML
# https://foundico.com/ico/Coincrowdit.HTML
# https://foundico.com/ico/Planes-Cloud.HTML
# https://foundico.com/ico/Kchin.HTML
# https://foundico.com/ico/AmberPort.HTML
# https://foundico.com/ico/AbioCoin.HTML
# https://foundico.com/ico/Hedge-Token.HTML
# https://foundico.com/ico/MyWill-Platform.HTML
# https://foundico.com/ico/ToTheMoon.HTML
# https://foundico.com/ico/ChainTrade.HTML
# https://foundico.com/ico/Real-Estate-Token.HTML
# https://foundico.com/ico/Global-Crypto-Bank.HTML
# https://foundico.com/ico/LydianCoin.HTML
# https://foundico.com/ico/LoanBit.HTML
# https://foundico.com/ico/The-NAGA.HTML
# https://foundico.com/ico/NEXTexchange.HTML
# https://foundico.com/ico/eGold.HTML
# https://foundico.com/ico/Volk.HTML
# https://foundico.com/ico/AIDA-Service.HTML
# https://foundico.com/ico/xshainge.html
# https://foundico.com/ico/VONE.HTML
# https://foundico.com/ico/Milkyway-Coin.HTML
# https://foundico.com/ico/Hitscoin.HTML
# https://foundico.com/ico/AurumCoin.HTML
# https://foundico.com/ico/Exindex.HTML
# https://foundico.com/ico/ElectionCoin.HTML
# https://foundico.com/ico/ENSBID.HTML
# https://foundico.com/ico/StaticICO.HTML
# https://foundico.com/ico/Adverx.HTML
# https://foundico.com/ico/Ribbon-Coin.HTML
# https://foundico.com/ico/Gas-Files.HTML
# https://foundico.com/ico/Investment-Platform-of-Nigeria.HTML
# https://foundico.com/ico/Lite-Eco-Ledger-Elements.HTML
# https://foundico.com/ico/Menuva.HTML
# https://foundico.com/ico/MangoStartups.HTML
# https://foundico.com/ico/EXMO.HTML
# https://foundico.com/ico/GramGold.HTML
# https://foundico.com/ico/Giftz.HTML
# https://foundico.com/ico/bostoken.html
# https://foundico.com/ico/EQUI.HTML
# https://foundico.com/ico/Lavenir.HTML
# https://foundico.com/ico/CryoCloudCoin.HTML
# https://foundico.com/ico/crypt2pos.HTML
# https://foundico.com/ico/TradeNetCoin.HTML
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/tilx---magic-and-social-services.html
# https://foundico.com/ico/Phi-Gold-Mining.HTML
# https://foundico.com/ico/Clean-SL8.HTML
# https://foundico.com/ico/Punta-Cana-Trading.HTML
# https://foundico.com/ico/remittance-gateway-.html
# https://foundico.com/ico/Alt-Estate.HTML
# https://foundico.com/ico/Crystal-Token.HTML
# https://foundico.com/ico/CNC.HTML
# https://foundico.com/ico/Morpheus-Network.HTML
# https://foundico.com/ico/GlobalSpy.HTML
# https://foundico.com/ico/IQuiCoin.HTML
# https://foundico.com/ico/HODLER-TECH.HTML
# https://foundico.com/ico/D-Central-Capital.HTML
# https://foundico.com/ico/IndiaStocksCoin.HTML
# https://foundico.com/ico/Vendoreum.HTML
# https://foundico.com/ico/TIMECOIN.HTML
# https://foundico.com/ico/The-GlobeToken-Project.HTML
# https://foundico.com/ico/All-Stocks-Network.HTML
# https://foundico.com/ico/WHEN-Token.HTML
# https://foundico.com/ico/Red-Pill-Coin.HTML
# https://foundico.com/ico/Viva-Network.HTML
# https://foundico.com/ico/Ethereum-Anonymizer.HTML
# https://foundico.com/ico/Crypton-VC.HTML
# https://foundico.com/ico/Bithemoth-Exchange.HTML
# https://foundico.com/ico/StoneToken.HTML
# https://foundico.com/ico/Export-Online.HTML
# https://foundico.com/ico/ZNC-Token.HTML
# https://foundico.com/ico/WRIO-Internet-OS.HTML
# https://foundico.com/ico/VirtualStaking.HTML
# https://foundico.com/ico/Abeona.HTML
# https://foundico.com/ico/MarsTerminal.HTML
# https://foundico.com/ico/Shanghai-Cooperation-Coin.HTML
# https://foundico.com/ico/CiCoin.HTML
# https://foundico.com/ico/Midas-Protocol.HTML
# https://foundico.com/ico/nCrypt-Club.HTML
# https://foundico.com/ico/iCasting-Talent-Token.HTML
# https://foundico.com/ico/Ethernet-Cash.HTML
# https://foundico.com/ico/Ethereum-Pink.HTML
# https://foundico.com/ico/ONEPAY.HTML
# https://foundico.com/ico/Breezecoin.HTML
# https://foundico.com/ico/Hodler-Mining.HTML
# https://foundico.com/ico/Enumbra.HTML
# https://foundico.com/ico/Ternion.HTML
# https://foundico.com/ico/Ubanx.HTML
# https://foundico.com/ico/HAWKOIN.HTML
# https://foundico.com/ico/Clear-Shop-Vision-ltd.HTML
# https://foundico.com/ico/SunX.HTML
# https://foundico.com/ico/RAD-Lending-Inc.HTML
# https://foundico.com/ico/GastroAdvisor.HTML
# https://foundico.com/ico/Upstake.HTML
# https://foundico.com/ico/Briastorm.HTML
# https://foundico.com/ico/Neuroseed.HTML
# https://foundico.com/ico/Dealjoy.HTML
# https://foundico.com/ico/Orvium.HTML
# https://foundico.com/ico/DrupeCoin.HTML
# https://foundico.com/ico/MODULE.HTML
# https://foundico.com/ico/Museums-Chain.HTML
# https://foundico.com/ico/CEREAL.HTML
# https://foundico.com/ico/ECX-Token.HTML
# https://foundico.com/ico/EJA-COIN.HTML
# https://foundico.com/ico/ROAR.HTML
# https://foundico.com/ico/LENDELTA.HTML
# https://foundico.com/ico/PayPerBlock.HTML
# https://foundico.com/ico/BIT-MONEY.HTML
# https://foundico.com/ico/Land-LayBy-Listing.HTML
# https://foundico.com/ico/Echarge.HTML
# https://foundico.com/ico/CarHash.HTML
# https://foundico.com/ico/First-Investment-Token.HTML
# https://foundico.com/ico/Advanced-Initial-Offering.HTML
# https://foundico.com/ico/NATA.HTML
# https://foundico.com/ico/Magnify-Wallet.HTML
# https://foundico.com/ico/FinTech-Coins.HTML
# https://foundico.com/ico/GetDoIt.HTML
# https://foundico.com/ico/Lesfex-Exchange.HTML
# https://foundico.com/ico/weiDex.HTML
# https://foundico.com/ico/HAJJ-coin.HTML
# https://foundico.com/ico/AGRIC.HTML
# https://foundico.com/ico/Alpha-X.HTML
# https://foundico.com/ico/ConnectWealth.HTML
# https://foundico.com/ico/MPCX-Platform.HTML
# https://foundico.com/ico/Will-Token.HTML
# https://foundico.com/ico/FruitionToken.HTML
# https://foundico.com/ico/awaxx.HTML
# https://foundico.com/ico/nominex.HTML
# https://foundico.com/ico/stegos.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/moneytap%20token.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/neoplace.html
# https://foundico.com/ico/BitValve.HTML
# https://foundico.com/ico/Elysian.HTML
# https://foundico.com/ico/Upthinity.HTML
# https://foundico.com/ico/Medipedia.HTML
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/graft%20blockchain.html
# https://foundico.com/ico/Snovio.HTML
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/aceh%20coin.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/gleec%20coin.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/myriads.io.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/the%20tok%20app.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/universe%20coin%20ieo.html
# https://foundico.com/ico/JioCoin.HTML
# https://foundico.com/ico/SUPERIUM.HTML
# https://foundico.com/ico/Woonkly.HTML
# https://foundico.com/ico/Plenus.HTML
# https://foundico.com/ico/Geco-one.HTML
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/bnc%20token.html
# OOps: Something Else 404 Client Error: Not Found for url: https://foundico.com/ico/instant%20assets%20tokens.html
# https://foundico.com/ico/SpaceGold.HTML
# https://foundico.com/ico/Causee.HTML

# %%
FoundicoFound = []
tam_failed = len(failed_foundico_urls)
ammntFoundico = len(DataFoundico)

for i in range(ammntFoundico - 1):
    notFound = True
    j = 0
    while notFound and j < tam_failed:
        if (DataFoundico[i][2] != failed_foundico_urls[j]):
            FoundicoFound.append(DataFoundico[i])
            notFound = False
        else:
            print(failed_foundico_urls[j])
            j = j+1
# Out:
# https://foundico.com/ico/GreenEnergy.HTML

# %%
tam_found = len(FoundicoFound)
for i in range(tam_found-1):
    AllData.append(FoundicoFound[i])

# %%
len(AllData)
# Out:
# 6357

# %%
import csv 
tam = len(AllData)

icos_esg = []
icos_esg.append(['id', 'name', 'url', 'ESG', 'E', 'S', 'G'])

for i in range(tam):  
    icos_esg.append(AllData[i])
path = '../../data/'
filename = path+'icobase/icos_esg_09_04.csv'
with open(filename, 'w', newline="") as newfile:
    csvwriter = csv.writer(newfile)
    csvwriter.writerows(icos_esg)
newfile.close()

# %%
failed_urls = []

for i in range(ammntResrICOs-1):
    url = RestOfAllData[i][2]
    response = requests.get(url)
    if response:
        # parse the HTML content of the page
        soup = BeautifulSoup(response.content, "html.parser")
        product_search_element = soup.find(id="company-description")
        list_item = soup.find('div', attrs={'class': 'company-description'})
        text = list_item.text.strip()
        ESG = ESG_Calculator(text)
        RestOfAllData[i][3] = np.round(ESG[0], 3)
        RestOfAllData[i][4] = np.round(ESG[1], 3)
        RestOfAllData[i][5] = np.round(ESG[2], 3)
        RestOfAllData[i][6] = np.round(ESG[3], 3)
        #mostreESG(ESG)
    else:
        failed_urls.append(url)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [223], in <cell line: 2>()
#       1 failed_urls = []
#       2 for i in range(ammntResrICOs-1):
# ----> 3     url = RestOfAllData[i][2]
#       4     response = requests.get(url)
#       5     if response:
#       6         # parse the HTML content of the page
#
# IndexError: list index out of range
